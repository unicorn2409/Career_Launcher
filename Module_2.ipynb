# %% [markdown]
# # 2.1

# %%
import pandas as pd
from datetime import datetime
from functools import partial

data3=pd.read_csv(r"D:\Study\TY_BTECH\Resume\Internship\CL_Data_School\week2.csv") #loading week2.csv file
del data3['Unnamed: 0']
duplicate_data = data3 
data3.head()#loading first few lines of week2.csv file
# Out:
#   Symbol Series        Date  Prev Close  Open Price  High Price  Low Price  \
# 0    TCS     EQ  2017-05-15     2360.65      2375.1     2377.95    2341.60
# 1    TCS     EQ  2017-05-16     2365.10      2380.0     2435.00    2373.45
# 2    TCS     EQ  2017-05-17     2429.15      2433.5     2460.75    2423.00
# 3    TCS     EQ  2017-05-18     2455.35      2450.0     2572.00    2442.25
# 4    TCS     EQ  2017-05-19     2536.20      2536.2     2540.55    2486.00
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     2368.00      2365.10        2352.60                 908802
# 1     2425.10      2429.15        2410.26                1800513
# 2     2450.00      2455.35        2443.31                1438099
# 3     2525.00      2536.20        2525.78                2569297
# 4     2503.85      2507.15        2506.58                 893022
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  Year  \
# 0  2.138043e+09          30047           712450                   78.39  2017
# 1  4.339703e+09          58476          1167534                   64.84  2017
# 2  3.513729e+09          86412          1031752                   71.74  2017
# 3  6.489478e+09         111566          1135613                   44.20  2017
# 4  2.238430e+09          63112           517461                   57.94  2017
#
#    Month         VWAP  Day_Perc_Change                Trend
# 0      5  2365.100000         0.000000  Slight or No change
# 1      5  2407.665319         0.027081  Slight or No change
# 2      5  2424.199789         0.010786  Slight or No change
# 3      5  2467.042455         0.032928  Slight or No change
# 4      5  2471.749180        -0.011454  Slight or No change

# %%
data3.Date.dtypes
# Out:
# dtype('O')

# %%
data3['Date']=pd.to_datetime(data3['Date'])
data3.Date.dtypes
# Out:
# dtype('<M8[ns]')

# %%
data3.set_index('Date', inplace=True)
data3
# Out:
#            Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-15    TCS     EQ     2360.65     2375.10     2377.95    2341.60
# 2017-05-16    TCS     EQ     2365.10     2380.00     2435.00    2373.45
# 2017-05-17    TCS     EQ     2429.15     2433.50     2460.75    2423.00
# 2017-05-18    TCS     EQ     2455.35     2450.00     2572.00    2442.25
# 2017-05-19    TCS     EQ     2536.20     2536.20     2540.55    2486.00
# ...           ...    ...         ...         ...         ...        ...
# 2019-05-07    TCS     EQ     2157.85     2160.05     2184.35    2138.80
# 2019-05-08    TCS     EQ     2151.95     2151.00     2168.00    2130.40
# 2019-05-09    TCS     EQ     2152.85     2145.00     2184.10    2136.10
# 2019-05-10    TCS     EQ     2172.55     2175.00     2192.00    2125.85
# 2019-05-13    TCS     EQ     2135.80     2133.00     2167.00    2121.65
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Date
# 2017-05-15     2368.00      2365.10        2352.60                 908802
# 2017-05-16     2425.10      2429.15        2410.26                1800513
# 2017-05-17     2450.00      2455.35        2443.31                1438099
# 2017-05-18     2525.00      2536.20        2525.78                2569297
# 2017-05-19     2503.85      2507.15        2506.58                 893022
# ...                ...          ...            ...                    ...
# 2019-05-07     2154.00      2151.95        2163.53                2201698
# 2019-05-08     2156.00      2152.85        2151.85                1824895
# 2019-05-09     2171.20      2172.55        2166.98                2264162
# 2019-05-10     2130.25      2135.80        2161.83                2039633
# 2019-05-13     2134.00      2128.75        2143.87                1701744
#
#                 Turnover  No. of Trades  Deliverable Qty  \
# Date
# 2017-05-15  2.138043e+09          30047           712450
# 2017-05-16  4.339703e+09          58476          1167534
# 2017-05-17  3.513729e+09          86412          1031752
# 2017-05-18  6.489478e+09         111566          1135613
# 2017-05-19  2.238430e+09          63112           517461
# ...                  ...            ...              ...
# 2019-05-07  4.763441e+09          86096           975603
# 2019-05-08  3.926902e+09          77713           781526
# 2019-05-09  4.906405e+09         106297          1251459
# 2019-05-10  4.409349e+09          85446           873181
# 2019-05-13  3.648325e+09          74014           677242
#
#             % Dly Qt to Traded Qty  Year  Month         VWAP  Day_Perc_Change  \
# Date
# 2017-05-15                   78.39  2017      5  2365.100000         0.000000
# 2017-05-16                   64.84  2017      5  2407.665319         0.027081
# 2017-05-17                   71.74  2017      5  2424.199789         0.010786
# 2017-05-18                   44.20  2017      5  2467.042455         0.032928
# 2017-05-19                   57.94  2017      5  2471.749180        -0.011454
# ...                            ...   ...    ...          ...              ...
# 2019-05-07                   44.31  2019      5  2282.852775        -0.002734
# 2019-05-08                   42.83  2019      5  2282.628633         0.000418
# 2019-05-09                   55.27  2019      5  2282.393661         0.009151
# 2019-05-10                   42.81  2019      5  2282.112317        -0.016916
# 2019-05-13                   39.80  2019      5  2281.867135        -0.003301
#
#                           Trend
# Date
# 2017-05-15  Slight or No change
# 2017-05-16  Slight or No change
# 2017-05-17  Slight or No change
# 2017-05-18  Slight or No change
# 2017-05-19  Slight or No change
# ...                         ...
# 2019-05-07  Slight or No change
# 2019-05-08  Slight or No change
# 2019-05-09  Slight or No change
# 2019-05-10  Slight or No change
# 2019-05-13  Slight or No change
#
# [494 rows x 19 columns]

# %%
#Data Visualization
import matplotlib.pyplot as plt
# %matplotlib inline    
#magic function in python, set the backend of matplotlib to the insline backend
data3['Close Price'].plot(label = 'module2',figsize=(16,8),title='Closing Price with respect to Date')
plt.legend()

# %%
#Drastic Changes
data3['Close Price'].diff().abs().sort_values(ascending = False)
# Out:
# Date
# 2018-05-31    1773.05
# 2018-04-20     211.30
# 2018-03-13     165.35
# 2018-01-22     157.10
# 2018-04-12     125.10
#                ...
# 2017-09-04       0.25
# 2018-03-14       0.10
# 2019-03-19       0.00
# 2019-04-03       0.00
# 2017-05-15        NaN
# Name: Close Price, Length: 494, dtype: float64

# %%
#News 
import bs4
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests 

url_2018_05_04 ='https://www.moneycontrol.com/news/business/stocks/buy-bharti-airtel-target-of-rs-710-motilal-oswal-5291611.html'
r = requests.get(url_2018_05_04)
    
soup = BeautifulSoup(r.content,"html.parser")
stock_news_title_container = soup.find('div',class_ = 'article_box')
stock_news_subhead_container = soup.find('div',class_ = 'brk_wraper clearfix')
stock_news_body_container = soup.find('div',class_ = 'arti-flow')

print("Printing news for only 4 dates since the 5th date has no news")
print("Obtaining news from Money Control")
print("News for 2018-05-04 ")
print("Only 1 news is available on this date")
print('\n')
print("Title:")
print (stock_news_title_container.h1.text)
print('\n')
print("Subject:")
print (stock_news_subhead_container.h2.text)
print('\n')
print("Report:")
print (stock_news_body_container.select_one("p:nth-of-type(2)").text)

print("-------------------------------------------------------------")
# Out:
# Printing news for only 4 dates since the 5th date has no news
# Obtaining news from Money Control
# News for 2018-05-04
# Only 1 news is available on this date
#
#
# Title:
# Buy Bharti Airtel; target of Rs 710: Motilal Oswal
#
#
# Subject:
# Motilal Oswal is bullish on Bharti Airtel has recommended buy rating on the stock with a target price of Rs 710 in its research report dated May 19, 2020.
#
#
# Report:
# The price hikes taken in Dec’19 and healthy 4G subscriber adds improved ARPU, which in turn led to an increase in EBITDA. However, capex doubled QoQ to INR113b, which resulted in operating FCF turning negative. Further, the QIP amount was utilized to partly pay AGR liabilities. - We largely maintain our FY21E consol. EBITDA estimates building ARPU increase of 8% on favorable 4G subscriber mix. We increase our FY22E EBITDA by 5% with higher ARPU increase of 14%, after building in some tariff increase.
# -------------------------------------------------------------

# %% [markdown]
# # 2.2

# %%
data3
# Out:
#            Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-15    TCS     EQ     2360.65     2375.10     2377.95    2341.60
# 2017-05-16    TCS     EQ     2365.10     2380.00     2435.00    2373.45
# 2017-05-17    TCS     EQ     2429.15     2433.50     2460.75    2423.00
# 2017-05-18    TCS     EQ     2455.35     2450.00     2572.00    2442.25
# 2017-05-19    TCS     EQ     2536.20     2536.20     2540.55    2486.00
# ...           ...    ...         ...         ...         ...        ...
# 2019-05-07    TCS     EQ     2157.85     2160.05     2184.35    2138.80
# 2019-05-08    TCS     EQ     2151.95     2151.00     2168.00    2130.40
# 2019-05-09    TCS     EQ     2152.85     2145.00     2184.10    2136.10
# 2019-05-10    TCS     EQ     2172.55     2175.00     2192.00    2125.85
# 2019-05-13    TCS     EQ     2135.80     2133.00     2167.00    2121.65
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Date
# 2017-05-15     2368.00      2365.10        2352.60                 908802
# 2017-05-16     2425.10      2429.15        2410.26                1800513
# 2017-05-17     2450.00      2455.35        2443.31                1438099
# 2017-05-18     2525.00      2536.20        2525.78                2569297
# 2017-05-19     2503.85      2507.15        2506.58                 893022
# ...                ...          ...            ...                    ...
# 2019-05-07     2154.00      2151.95        2163.53                2201698
# 2019-05-08     2156.00      2152.85        2151.85                1824895
# 2019-05-09     2171.20      2172.55        2166.98                2264162
# 2019-05-10     2130.25      2135.80        2161.83                2039633
# 2019-05-13     2134.00      2128.75        2143.87                1701744
#
#                 Turnover  No. of Trades  Deliverable Qty  \
# Date
# 2017-05-15  2.138043e+09          30047           712450
# 2017-05-16  4.339703e+09          58476          1167534
# 2017-05-17  3.513729e+09          86412          1031752
# 2017-05-18  6.489478e+09         111566          1135613
# 2017-05-19  2.238430e+09          63112           517461
# ...                  ...            ...              ...
# 2019-05-07  4.763441e+09          86096           975603
# 2019-05-08  3.926902e+09          77713           781526
# 2019-05-09  4.906405e+09         106297          1251459
# 2019-05-10  4.409349e+09          85446           873181
# 2019-05-13  3.648325e+09          74014           677242
#
#             % Dly Qt to Traded Qty  Year  Month         VWAP  Day_Perc_Change  \
# Date
# 2017-05-15                   78.39  2017      5  2365.100000         0.000000
# 2017-05-16                   64.84  2017      5  2407.665319         0.027081
# 2017-05-17                   71.74  2017      5  2424.199789         0.010786
# 2017-05-18                   44.20  2017      5  2467.042455         0.032928
# 2017-05-19                   57.94  2017      5  2471.749180        -0.011454
# ...                            ...   ...    ...          ...              ...
# 2019-05-07                   44.31  2019      5  2282.852775        -0.002734
# 2019-05-08                   42.83  2019      5  2282.628633         0.000418
# 2019-05-09                   55.27  2019      5  2282.393661         0.009151
# 2019-05-10                   42.81  2019      5  2282.112317        -0.016916
# 2019-05-13                   39.80  2019      5  2281.867135        -0.003301
#
#                           Trend
# Date
# 2017-05-15  Slight or No change
# 2017-05-16  Slight or No change
# 2017-05-17  Slight or No change
# 2017-05-18  Slight or No change
# 2017-05-19  Slight or No change
# ...                         ...
# 2019-05-07  Slight or No change
# 2019-05-08  Slight or No change
# 2019-05-09  Slight or No change
# 2019-05-10  Slight or No change
# 2019-05-13  Slight or No change
#
# [494 rows x 19 columns]

# %%
data3.reset_index()
# Out:
#           Date Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# 0   2017-05-15    TCS     EQ     2360.65     2375.10     2377.95    2341.60
# 1   2017-05-16    TCS     EQ     2365.10     2380.00     2435.00    2373.45
# 2   2017-05-17    TCS     EQ     2429.15     2433.50     2460.75    2423.00
# 3   2017-05-18    TCS     EQ     2455.35     2450.00     2572.00    2442.25
# 4   2017-05-19    TCS     EQ     2536.20     2536.20     2540.55    2486.00
# ..         ...    ...    ...         ...         ...         ...        ...
# 489 2019-05-07    TCS     EQ     2157.85     2160.05     2184.35    2138.80
# 490 2019-05-08    TCS     EQ     2151.95     2151.00     2168.00    2130.40
# 491 2019-05-09    TCS     EQ     2152.85     2145.00     2184.10    2136.10
# 492 2019-05-10    TCS     EQ     2172.55     2175.00     2192.00    2125.85
# 493 2019-05-13    TCS     EQ     2135.80     2133.00     2167.00    2121.65
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       2368.00      2365.10        2352.60                 908802
# 1       2425.10      2429.15        2410.26                1800513
# 2       2450.00      2455.35        2443.31                1438099
# 3       2525.00      2536.20        2525.78                2569297
# 4       2503.85      2507.15        2506.58                 893022
# ..          ...          ...            ...                    ...
# 489     2154.00      2151.95        2163.53                2201698
# 490     2156.00      2152.85        2151.85                1824895
# 491     2171.20      2172.55        2166.98                2264162
# 492     2130.25      2135.80        2161.83                2039633
# 493     2134.00      2128.75        2143.87                1701744
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty  \
# 0    2.138043e+09          30047           712450                   78.39
# 1    4.339703e+09          58476          1167534                   64.84
# 2    3.513729e+09          86412          1031752                   71.74
# 3    6.489478e+09         111566          1135613                   44.20
# 4    2.238430e+09          63112           517461                   57.94
# ..            ...            ...              ...                     ...
# 489  4.763441e+09          86096           975603                   44.31
# 490  3.926902e+09          77713           781526                   42.83
# 491  4.906405e+09         106297          1251459                   55.27
# 492  4.409349e+09          85446           873181                   42.81
# 493  3.648325e+09          74014           677242                   39.80
#
#      Year  Month         VWAP  Day_Perc_Change                Trend
# 0    2017      5  2365.100000         0.000000  Slight or No change
# 1    2017      5  2407.665319         0.027081  Slight or No change
# 2    2017      5  2424.199789         0.010786  Slight or No change
# 3    2017      5  2467.042455         0.032928  Slight or No change
# 4    2017      5  2471.749180        -0.011454  Slight or No change
# ..    ...    ...          ...              ...                  ...
# 489  2019      5  2282.852775        -0.002734  Slight or No change
# 490  2019      5  2282.628633         0.000418  Slight or No change
# 491  2019      5  2282.393661         0.009151  Slight or No change
# 492  2019      5  2282.112317        -0.016916  Slight or No change
# 493  2019      5  2281.867135        -0.003301  Slight or No change
#
# [494 rows x 20 columns]

# %%
data4=pd.read_csv(r"D:\Study\TY_BTECH\Resume\Internship\CL_Data_School\week2.csv")

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize=(20,5))
plt.stem(data4.Date, data4['Day_Perc_Change'])
# Out:
# C:\Users\unicorn\anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# <StemContainer object of 3 artists>

# %% [markdown]
# # 2.3

# %%
plt.figure(figsize=(20,10))
plt.stem(data4.Date, data4['Total Traded Quantity'])
# Out:
# C:\Users\unicorn\anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <StemContainer object of 3 artists>

# %%
plt.figure(figsize=(20,10))
plt.stem(data4['Total Traded Quantity'])
plt.show()
plt.figure(figsize=(20,10))
plt.stem(data4.Date, data4['Day_Perc_Change'])
plt.show()
# Out:
# C:\Users\unicorn\anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# C:\Users\unicorn\anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """

# %%
plt.figure(figsize=(20,10))
plt.stem(data4['Day_Perc_Change'],data4['Total Traded Quantity'])
plt.show()
plt.figure(figsize=(20,10))
plt.stem(data4['Total Traded Quantity'],data4['Day_Perc_Change'])
plt.show()
# Out:
# C:\Users\unicorn\anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# C:\Users\unicorn\anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """

# %%
plt.figure(figsize=(20,10))
plt.plot(data4['Day_Perc_Change'],data4['Total Traded Quantity'])
plt.show()
plt.figure(figsize=(20,10))
plt.plot(data4['Total Traded Quantity'],data4['Day_Perc_Change'])
plt.show()

# %% [markdown]
# # 2.4

# %%
import matplotlib.pyplot as plt
from collections import Counter

Trend = ['Postive','Negative','Breakout Bull','Breakout Bear','Among top losers','Among top gainers','Slight or No Change','Slight Positive','Slight Negative']
Trend_to_list = data4['Trend'].tolist()
counts = Counter(Trend_to_list)
counts
# Out:
# Counter({'Slight or No change': 494})

# %%
# So we only have 1 trend so there will be only 1 color pie chart 

counter = [494]
labels= ['Slight or No change']
colors = ['r']
plt.figure(figsize=(20,10))
plt.pie(counter, labels=labels,colors=colors,startangle=90, autopct='%.1f%%')
plt.show()

# %%
# We will find the average of each trend type
# here we only have 1 trend which is Slight or No change hence only 1 bar graph

import matplotlib.pyplot as plt
table = data4.groupby(['Trend'])['Total Traded Quantity']
table.describe()
# Out:
#                      count          mean           std      min       25%  \
# Trend
# Slight or No change  494.0  2.154751e+06  2.579232e+06  43411.0  936538.0
#
#                            50%        75%         max
# Trend
# Slight or No change  1696750.0  2622279.0  44033577.0

# %%
plt.figure(figsize=(20,10))
data4.groupby(['Trend'])['Total Traded Quantity'].mean().plot.bar()

# %%
plt.figure(figsize=(20,10))
data4.groupby(['Trend'])['Total Traded Quantity'].median().plot.bar()

# %% [markdown]
# # 2.5

# %%
#Histogram
plt.figure(figsize=(20,10))
plt.hist(data4['Day_Perc_Change'])
plt.show()

# %% [markdown]
# # 2.6

# %%
import pandas as pd
wipro_data = pd.read_csv('D:\\Study\\TY_BTECH\\Resume\\Internship\\CL_Data_School\\ML_Project\\wipro_stock_data.csv')
tcs_data = pd.read_csv('D:\\Study\\TY_BTECH\Resume\\Internship\\CL_Data_School\\ML_Project\\tcs_stock_data.csv')
itc_data = pd.read_csv(r'D:\\Study\\TY_BTECH\\Resume\\Internship\\CL_Data_School\\ML_Project\\itc_stock_data.csv')
cub_data = pd.read_csv(r'D:\\Study\\TY_BTECH\\Resume\\Internship\\CL_Data_School\\ML_Project\\cub_stock_data.csv')
airtel_data = pd.read_csv(r'D:\\Study\\TY_BTECH\\Resume\\Internship\\CL_Data_School\\ML_Project\\airtel_stock_data.csv')

# %%
wipro_data
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0    WIPRO     EQ  06-Jul-2017      257.80      257.80      260.05     255.85
# 1    WIPRO     EQ  07-Jul-2017      257.75      255.10      258.25     255.00
# 2    WIPRO     EQ  10-Jul-2017      257.70      260.00      268.95     257.00
# 3    WIPRO     EQ  11-Jul-2017      268.25      266.20      273.50     262.10
# 4    WIPRO     EQ  12-Jul-2017      263.20      263.70      265.80     261.30
# ..     ...    ...          ...         ...         ...         ...        ...
# 490  WIPRO     EQ  01-Jul-2019      280.50      281.60      283.40     280.95
# 491  WIPRO     EQ  02-Jul-2019      282.00      282.45      285.00     281.70
# 492  WIPRO     EQ  03-Jul-2019      284.25      284.90      285.60     282.05
# 493  WIPRO     EQ  04-Jul-2019      282.85      283.00      284.90     282.00
# 494  WIPRO     EQ  05-Jul-2019      283.85      284.00      284.55     271.00
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0        256.50       257.75         258.02                1649570
# 1        257.10       257.70         257.36                1458678
# 2        268.50       268.25         266.40                 667432
# 3        264.00       263.20         267.63                4060405
# 4        263.40       263.80         263.40                1189091
# ..          ...          ...            ...                    ...
# 490      282.15       282.00         282.14                1735921
# 491      284.30       284.25         283.86                2609369
# 492      282.65       282.85         283.25                1258276
# 493      283.60       283.85         283.77                1628331
# 494      271.75       271.85         275.86                4585463
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    4.256266e+08          16693           965007                   58.50
# 1    3.754085e+08          19295           957019                   65.61
# 2    1.778045e+08           6517           408579                   61.22
# 3    1.086678e+09          53473          2387366                   58.80
# 4    3.132094e+08          38856           647523                   54.46
# ..            ...            ...              ...                     ...
# 490  4.897758e+08          33665           955355                   55.03
# 491  7.407040e+08          38881          1219656                   46.74
# 492  3.564106e+08          21561           505062                   40.14
# 493  4.620724e+08          24896           961449                   59.05
# 494  1.264956e+09          69062          2011218                   43.86
#
# [495 rows x 15 columns]

# %%
tcs_data
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0      TCS     EQ  06-Jul-2017     2356.00      2359.0     2361.90    2340.10
# 1      TCS     EQ  07-Jul-2017     2347.55      2350.0     2356.45    2325.50
# 2      TCS     EQ  10-Jul-2017     2331.95      2341.0     2444.90    2341.00
# 3      TCS     EQ  11-Jul-2017     2434.95      2426.0     2514.80    2426.00
# 4      TCS     EQ  12-Jul-2017     2475.80      2482.5     2483.30    2430.10
# ..     ...    ...          ...         ...         ...         ...        ...
# 490    TCS     EQ  01-Jul-2019     2227.20      2235.0     2255.00    2206.60
# 491    TCS     EQ  02-Jul-2019     2239.55      2244.9     2257.00    2216.45
# 492    TCS     EQ  03-Jul-2019     2252.10      2252.2     2258.80    2232.00
# 493    TCS     EQ  04-Jul-2019     2237.65      2234.0     2252.00    2230.10
# 494    TCS     EQ  05-Jul-2019     2242.65      2247.0     2250.00    2140.00
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       2350.05      2347.55        2348.75                 513394
# 1       2332.00      2331.95        2343.49                 616045
# 2       2435.00      2434.95        2426.54                 398392
# 3       2482.50      2475.80        2478.13                1768752
# 4       2441.00      2439.45        2453.34                1323225
# ..          ...          ...            ...                    ...
# 490     2233.05      2239.55        2237.15                2769940
# 491     2254.30      2252.10        2237.79                1771746
# 492     2234.00      2237.65        2242.16                1656881
# 493     2241.00      2242.65        2241.04                 984140
# 494     2166.85      2163.10        2179.39                4088470
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    1.205835e+09          26826           342973                   66.81
# 1    1.443698e+09          52731           417958                   67.85
# 2    9.667144e+08          12486           188289                   47.26
# 3    4.383195e+09          96054           937311                   52.99
# 4    3.246316e+09          62259           926229                   70.00
# ..            ...            ...              ...                     ...
# 490  6.196759e+09         129268          1579799                   57.03
# 491  3.964797e+09          97184           816451                   46.08
# 492  3.714997e+09          87941           739089                   44.61
# 493  2.205502e+09          59990           352899                   35.86
# 494  8.910375e+09         160276          1736073                   42.46
#
# [495 rows x 15 columns]

# %%
itc_data
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0      ITC     EQ  06-Jul-2017      331.05      334.30      338.75     331.30
# 1      ITC     EQ  07-Jul-2017      337.10      338.00      338.20     333.05
# 2      ITC     EQ  10-Jul-2017      334.30      341.00      367.70     331.00
# 3      ITC     EQ  11-Jul-2017      333.30      335.00      335.05     330.00
# 4      ITC     EQ  12-Jul-2017      330.40      328.40      333.60     327.40
# ..     ...    ...          ...         ...         ...         ...        ...
# 490    ITC     EQ  01-Jul-2019      273.85      274.40      276.25     274.15
# 491    ITC     EQ  02-Jul-2019      274.95      275.35      275.65     273.20
# 492    ITC     EQ  03-Jul-2019      273.85      274.30      277.55     272.15
# 493    ITC     EQ  04-Jul-2019      276.70      277.45      278.25     275.20
# 494    ITC     EQ  05-Jul-2019      277.65      277.65      281.85     268.00
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0        337.10       337.10         336.17               13429462
# 1        334.50       334.30         334.92                9919790
# 2        333.00       333.30         333.45                1427399
# 3        330.20       330.40         331.28                8336685
# 4        329.80       328.85         329.19               10249263
# ..          ...          ...            ...                    ...
# 490      275.20       274.95         275.18                5042447
# 491      273.55       273.85         273.97                9976439
# 492      277.20       276.70         273.97               18120809
# 493      277.80       277.65         276.63                9697597
# 494      280.35       279.45         276.25               37047327
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    4.514575e+09         122886          8156576                   60.74
# 1    3.322371e+09          91378          6752966                   68.08
# 2    4.759600e+08          11885           679722                   47.62
# 3    2.761738e+09          85756          6032829                   72.36
# 4    3.373964e+09          90432          7048111                   68.77
# ..            ...            ...              ...                     ...
# 490  1.387580e+09          59587          2733563                   54.21
# 491  2.733288e+09          91998          7785650                   78.04
# 492  4.964575e+09          96803         13196093                   72.82
# 493  2.682609e+09          98989          6642736                   68.50
# 494  1.023441e+10         218676         20876681                   56.35
#
# [495 rows x 15 columns]

# %%
cub_data
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0      CUB     EQ  06-Jul-2017      179.60      179.25      181.00     178.80
# 1      CUB     EQ  07-Jul-2017      180.00      182.00      182.75     179.40
# 2      CUB     EQ  10-Jul-2017      181.55      180.00      185.35     180.00
# 3      CUB     EQ  11-Jul-2017      184.80      186.90      187.60     182.10
# 4      CUB     EQ  12-Jul-2017      183.50      184.40      184.75     182.30
# ..     ...    ...          ...         ...         ...         ...        ...
# 490    CUB     EQ  01-Jul-2019      218.05      218.50      219.15     214.70
# 491    CUB     EQ  02-Jul-2019      218.10      217.95      218.00     215.10
# 492    CUB     EQ  03-Jul-2019      215.80      217.95      218.00     212.65
# 493    CUB     EQ  04-Jul-2019      213.45      212.95      213.75     210.20
# 494    CUB     EQ  05-Jul-2019      210.75      211.00      211.40     203.90
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0        180.10       180.00         180.04                 513327
# 1        182.20       181.55         181.40                 150843
# 2        184.80       184.80         184.11                  90882
# 3        183.00       183.50         182.90                1138652
# 4        182.50       183.05         183.39                 313207
# ..          ...          ...            ...                    ...
# 490      217.90       218.10         217.07                 210062
# 491      215.80       215.80         216.57                 184540
# 492      212.85       213.45         215.78                 954745
# 493      210.25       210.75         212.14                1026703
# 494      206.10       205.95         208.09                1406371
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    9.241908e+07           4265           457813                   89.19
# 1    2.736324e+07           2074            88526                   58.69
# 2    1.673227e+07            776            68791                   75.69
# 3    2.082593e+08           5030           987514                   86.73
# 4    5.743804e+07           3905           244864                   78.18
# ..            ...            ...              ...                     ...
# 490  4.559752e+07           3858           103153                   49.11
# 491  3.996587e+07           8593           107555                   58.28
# 492  2.060188e+08           5585           884516                   92.64
# 493  2.178076e+08           4284           911802                   88.81
# 494  2.926456e+08          16658          1139576                   81.03
#
# [495 rows x 15 columns]

# %%
airtel_data
# Out:
#          Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    BHARTIARTL     EQ  06-Jul-2017      376.30      376.55      382.85
# 1    BHARTIARTL     EQ  07-Jul-2017      381.30      384.00      387.55
# 2    BHARTIARTL     EQ  10-Jul-2017      385.90      388.10      410.15
# 3    BHARTIARTL     EQ  11-Jul-2017      405.70      404.15      408.90
# 4    BHARTIARTL     EQ  12-Jul-2017      395.45      397.80      402.30
# ..          ...    ...          ...         ...         ...         ...
# 493  BHARTIARTL     EQ  01-Jul-2019      346.65      347.00      349.85
# 494  BHARTIARTL     EQ  02-Jul-2019      348.50      349.00      354.50
# 495  BHARTIARTL     EQ  03-Jul-2019      353.60      352.90      356.50
# 496  BHARTIARTL     EQ  04-Jul-2019      353.20      353.35      365.00
# 497  BHARTIARTL     EQ  05-Jul-2019      362.75      362.75      371.15
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       373.95      381.20       381.30         379.89                2162556
# 1       383.00      387.55       385.90         385.28                4371065
# 2       388.00      405.00       405.70         404.08                1901518
# 3       393.45      394.45       395.45         401.71                5565524
# 4       394.45      399.00       397.10         397.28                2608465
# ..         ...         ...          ...            ...                    ...
# 493     345.15      348.45       348.50         347.66                3405198
# 494     347.35      352.70       353.60         351.74                3745884
# 495     349.75      352.90       353.20         354.15                8317090
# 496     353.00      362.10       362.75         361.71                8407402
# 497     360.50      364.85       364.80         365.11                6751716
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    8.215367e+08          28573          1129739                   52.24
# 1    1.684069e+09          37883          3261760                   74.62
# 2    7.683562e+08          14555           881739                   46.37
# 3    2.235742e+09          68716          3113596                   55.94
# 4    1.036278e+09          39662          1147573                   43.99
# ..            ...            ...              ...                     ...
# 493  1.183867e+09          74444          1664891                   48.89
# 494  1.317578e+09          50799          1460631                   38.99
# 495  2.945468e+09          50960          5653437                   67.97
# 496  3.041005e+09          86438          3971490                   47.24
# 497  2.465131e+09          75154          3203297                   47.44
#
# [498 rows x 15 columns]

# %%
filter_tcs = tcs_data[tcs_data.Series == 'EQ']
filter_tcs
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0      TCS     EQ  06-Jul-2017     2356.00      2359.0     2361.90    2340.10
# 1      TCS     EQ  07-Jul-2017     2347.55      2350.0     2356.45    2325.50
# 2      TCS     EQ  10-Jul-2017     2331.95      2341.0     2444.90    2341.00
# 3      TCS     EQ  11-Jul-2017     2434.95      2426.0     2514.80    2426.00
# 4      TCS     EQ  12-Jul-2017     2475.80      2482.5     2483.30    2430.10
# ..     ...    ...          ...         ...         ...         ...        ...
# 490    TCS     EQ  01-Jul-2019     2227.20      2235.0     2255.00    2206.60
# 491    TCS     EQ  02-Jul-2019     2239.55      2244.9     2257.00    2216.45
# 492    TCS     EQ  03-Jul-2019     2252.10      2252.2     2258.80    2232.00
# 493    TCS     EQ  04-Jul-2019     2237.65      2234.0     2252.00    2230.10
# 494    TCS     EQ  05-Jul-2019     2242.65      2247.0     2250.00    2140.00
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       2350.05      2347.55        2348.75                 513394
# 1       2332.00      2331.95        2343.49                 616045
# 2       2435.00      2434.95        2426.54                 398392
# 3       2482.50      2475.80        2478.13                1768752
# 4       2441.00      2439.45        2453.34                1323225
# ..          ...          ...            ...                    ...
# 490     2233.05      2239.55        2237.15                2769940
# 491     2254.30      2252.10        2237.79                1771746
# 492     2234.00      2237.65        2242.16                1656881
# 493     2241.00      2242.65        2241.04                 984140
# 494     2166.85      2163.10        2179.39                4088470
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    1.205835e+09          26826           342973                   66.81
# 1    1.443698e+09          52731           417958                   67.85
# 2    9.667144e+08          12486           188289                   47.26
# 3    4.383195e+09          96054           937311                   52.99
# 4    3.246316e+09          62259           926229                   70.00
# ..            ...            ...              ...                     ...
# 490  6.196759e+09         129268          1579799                   57.03
# 491  3.964797e+09          97184           816451                   46.08
# 492  3.714997e+09          87941           739089                   44.61
# 493  2.205502e+09          59990           352899                   35.86
# 494  8.910375e+09         160276          1736073                   42.46
#
# [495 rows x 15 columns]

# %%
filter_wipro = wipro_data[wipro_data.Series == 'EQ']
filter_wipro
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0    WIPRO     EQ  06-Jul-2017      257.80      257.80      260.05     255.85
# 1    WIPRO     EQ  07-Jul-2017      257.75      255.10      258.25     255.00
# 2    WIPRO     EQ  10-Jul-2017      257.70      260.00      268.95     257.00
# 3    WIPRO     EQ  11-Jul-2017      268.25      266.20      273.50     262.10
# 4    WIPRO     EQ  12-Jul-2017      263.20      263.70      265.80     261.30
# ..     ...    ...          ...         ...         ...         ...        ...
# 490  WIPRO     EQ  01-Jul-2019      280.50      281.60      283.40     280.95
# 491  WIPRO     EQ  02-Jul-2019      282.00      282.45      285.00     281.70
# 492  WIPRO     EQ  03-Jul-2019      284.25      284.90      285.60     282.05
# 493  WIPRO     EQ  04-Jul-2019      282.85      283.00      284.90     282.00
# 494  WIPRO     EQ  05-Jul-2019      283.85      284.00      284.55     271.00
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0        256.50       257.75         258.02                1649570
# 1        257.10       257.70         257.36                1458678
# 2        268.50       268.25         266.40                 667432
# 3        264.00       263.20         267.63                4060405
# 4        263.40       263.80         263.40                1189091
# ..          ...          ...            ...                    ...
# 490      282.15       282.00         282.14                1735921
# 491      284.30       284.25         283.86                2609369
# 492      282.65       282.85         283.25                1258276
# 493      283.60       283.85         283.77                1628331
# 494      271.75       271.85         275.86                4585463
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    4.256266e+08          16693           965007                   58.50
# 1    3.754085e+08          19295           957019                   65.61
# 2    1.778045e+08           6517           408579                   61.22
# 3    1.086678e+09          53473          2387366                   58.80
# 4    3.132094e+08          38856           647523                   54.46
# ..            ...            ...              ...                     ...
# 490  4.897758e+08          33665           955355                   55.03
# 491  7.407040e+08          38881          1219656                   46.74
# 492  3.564106e+08          21561           505062                   40.14
# 493  4.620724e+08          24896           961449                   59.05
# 494  1.264956e+09          69062          2011218                   43.86
#
# [495 rows x 15 columns]

# %%
filter_itc = itc_data[itc_data.Series == 'EQ']
filter_itc
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0      ITC     EQ  06-Jul-2017      331.05      334.30      338.75     331.30
# 1      ITC     EQ  07-Jul-2017      337.10      338.00      338.20     333.05
# 2      ITC     EQ  10-Jul-2017      334.30      341.00      367.70     331.00
# 3      ITC     EQ  11-Jul-2017      333.30      335.00      335.05     330.00
# 4      ITC     EQ  12-Jul-2017      330.40      328.40      333.60     327.40
# ..     ...    ...          ...         ...         ...         ...        ...
# 490    ITC     EQ  01-Jul-2019      273.85      274.40      276.25     274.15
# 491    ITC     EQ  02-Jul-2019      274.95      275.35      275.65     273.20
# 492    ITC     EQ  03-Jul-2019      273.85      274.30      277.55     272.15
# 493    ITC     EQ  04-Jul-2019      276.70      277.45      278.25     275.20
# 494    ITC     EQ  05-Jul-2019      277.65      277.65      281.85     268.00
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0        337.10       337.10         336.17               13429462
# 1        334.50       334.30         334.92                9919790
# 2        333.00       333.30         333.45                1427399
# 3        330.20       330.40         331.28                8336685
# 4        329.80       328.85         329.19               10249263
# ..          ...          ...            ...                    ...
# 490      275.20       274.95         275.18                5042447
# 491      273.55       273.85         273.97                9976439
# 492      277.20       276.70         273.97               18120809
# 493      277.80       277.65         276.63                9697597
# 494      280.35       279.45         276.25               37047327
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    4.514575e+09         122886          8156576                   60.74
# 1    3.322371e+09          91378          6752966                   68.08
# 2    4.759600e+08          11885           679722                   47.62
# 3    2.761738e+09          85756          6032829                   72.36
# 4    3.373964e+09          90432          7048111                   68.77
# ..            ...            ...              ...                     ...
# 490  1.387580e+09          59587          2733563                   54.21
# 491  2.733288e+09          91998          7785650                   78.04
# 492  4.964575e+09          96803         13196093                   72.82
# 493  2.682609e+09          98989          6642736                   68.50
# 494  1.023441e+10         218676         20876681                   56.35
#
# [495 rows x 15 columns]

# %%
filter_cub = cub_data[cub_data.Series == 'EQ']
filter_cub
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0      CUB     EQ  06-Jul-2017      179.60      179.25      181.00     178.80
# 1      CUB     EQ  07-Jul-2017      180.00      182.00      182.75     179.40
# 2      CUB     EQ  10-Jul-2017      181.55      180.00      185.35     180.00
# 3      CUB     EQ  11-Jul-2017      184.80      186.90      187.60     182.10
# 4      CUB     EQ  12-Jul-2017      183.50      184.40      184.75     182.30
# ..     ...    ...          ...         ...         ...         ...        ...
# 490    CUB     EQ  01-Jul-2019      218.05      218.50      219.15     214.70
# 491    CUB     EQ  02-Jul-2019      218.10      217.95      218.00     215.10
# 492    CUB     EQ  03-Jul-2019      215.80      217.95      218.00     212.65
# 493    CUB     EQ  04-Jul-2019      213.45      212.95      213.75     210.20
# 494    CUB     EQ  05-Jul-2019      210.75      211.00      211.40     203.90
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0        180.10       180.00         180.04                 513327
# 1        182.20       181.55         181.40                 150843
# 2        184.80       184.80         184.11                  90882
# 3        183.00       183.50         182.90                1138652
# 4        182.50       183.05         183.39                 313207
# ..          ...          ...            ...                    ...
# 490      217.90       218.10         217.07                 210062
# 491      215.80       215.80         216.57                 184540
# 492      212.85       213.45         215.78                 954745
# 493      210.25       210.75         212.14                1026703
# 494      206.10       205.95         208.09                1406371
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    9.241908e+07           4265           457813                   89.19
# 1    2.736324e+07           2074            88526                   58.69
# 2    1.673227e+07            776            68791                   75.69
# 3    2.082593e+08           5030           987514                   86.73
# 4    5.743804e+07           3905           244864                   78.18
# ..            ...            ...              ...                     ...
# 490  4.559752e+07           3858           103153                   49.11
# 491  3.996587e+07           8593           107555                   58.28
# 492  2.060188e+08           5585           884516                   92.64
# 493  2.178076e+08           4284           911802                   88.81
# 494  2.926456e+08          16658          1139576                   81.03
#
# [495 rows x 15 columns]

# %%
filter_airtel = airtel_data[airtel_data.Series == 'EQ']
filter_airtel
# Out:
#          Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    BHARTIARTL     EQ  06-Jul-2017      376.30      376.55      382.85
# 1    BHARTIARTL     EQ  07-Jul-2017      381.30      384.00      387.55
# 2    BHARTIARTL     EQ  10-Jul-2017      385.90      388.10      410.15
# 3    BHARTIARTL     EQ  11-Jul-2017      405.70      404.15      408.90
# 4    BHARTIARTL     EQ  12-Jul-2017      395.45      397.80      402.30
# ..          ...    ...          ...         ...         ...         ...
# 493  BHARTIARTL     EQ  01-Jul-2019      346.65      347.00      349.85
# 494  BHARTIARTL     EQ  02-Jul-2019      348.50      349.00      354.50
# 495  BHARTIARTL     EQ  03-Jul-2019      353.60      352.90      356.50
# 496  BHARTIARTL     EQ  04-Jul-2019      353.20      353.35      365.00
# 497  BHARTIARTL     EQ  05-Jul-2019      362.75      362.75      371.15
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       373.95      381.20       381.30         379.89                2162556
# 1       383.00      387.55       385.90         385.28                4371065
# 2       388.00      405.00       405.70         404.08                1901518
# 3       393.45      394.45       395.45         401.71                5565524
# 4       394.45      399.00       397.10         397.28                2608465
# ..         ...         ...          ...            ...                    ...
# 493     345.15      348.45       348.50         347.66                3405198
# 494     347.35      352.70       353.60         351.74                3745884
# 495     349.75      352.90       353.20         354.15                8317090
# 496     353.00      362.10       362.75         361.71                8407402
# 497     360.50      364.85       364.80         365.11                6751716
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    8.215367e+08          28573          1129739                   52.24
# 1    1.684069e+09          37883          3261760                   74.62
# 2    7.683562e+08          14555           881739                   46.37
# 3    2.235742e+09          68716          3113596                   55.94
# 4    1.036278e+09          39662          1147573                   43.99
# ..            ...            ...              ...                     ...
# 493  1.183867e+09          74444          1664891                   48.89
# 494  1.317578e+09          50799          1460631                   38.99
# 495  2.945468e+09          50960          5653437                   67.97
# 496  3.041005e+09          86438          3971490                   47.24
# 497  2.465131e+09          75154          3203297                   47.44
#
# [495 rows x 15 columns]

# %%
import pandas as pd

columns = ['WIPRO','TCS','ITC','CUB','AIRTEL']
close_prices_dataFrame = pd.DataFrame(columns = columns)
close_prices_dataFrame['WIPRO'] = filter_wipro['Close Price']
close_prices_dataFrame['TCS'] = filter_tcs['Close Price']
close_prices_dataFrame['ITC'] = filter_itc['Close Price']
close_prices_dataFrame['CUB'] = filter_cub['Close Price']
close_prices_dataFrame['AIRTEL'] = filter_airtel['Close Price']
close_prices_dataFrame.dropna()
# Out:
#       WIPRO      TCS     ITC     CUB  AIRTEL
# 0    257.75  2347.55  337.10  180.00  381.30
# 1    257.70  2331.95  334.30  181.55  385.90
# 2    268.25  2434.95  333.30  184.80  405.70
# 3    263.20  2475.80  330.40  183.50  395.45
# 4    263.80  2439.45  328.85  183.05  397.10
# ..      ...      ...     ...     ...     ...
# 490  282.00  2239.55  274.95  218.10  345.55
# 491  284.25  2252.10  273.85  215.80  348.65
# 492  282.85  2237.65  276.70  213.45  346.65
# 493  283.85  2242.65  277.65  210.75  348.50
# 494  271.85  2163.10  279.45  205.95  353.60
#
# [492 rows x 5 columns]

# %%
pct_change_dataFrame = close_prices_dataFrame.pct_change().fillna(0)
pct_change_dataFrame.dropna()
# Out:
#         WIPRO       TCS       ITC       CUB    AIRTEL
# 0    0.000000  0.000000  0.000000  0.000000  0.000000
# 1   -0.000194 -0.006645 -0.008306  0.008611  0.012064
# 2    0.040939  0.044169 -0.002991  0.017901  0.051309
# 3   -0.018826  0.016777 -0.008701 -0.007035 -0.025265
# 4    0.002280 -0.014682 -0.004691 -0.002452  0.004172
# ..        ...       ...       ...       ...       ...
# 490  0.005348  0.005545  0.004017  0.000229 -0.008749
# 491  0.007979  0.005604 -0.004001 -0.010546  0.008971
# 492 -0.004925 -0.006416  0.010407 -0.010890 -0.005736
# 493  0.003535  0.002234  0.003433 -0.012649  0.005337
# 494 -0.042276 -0.035471  0.006483 -0.022776  0.014634
#
# [495 rows x 5 columns]

# %%
import seaborn as sns

sns.set(color_codes=True)
sns.pairplot(pct_change_dataFrame)

# %% [markdown]
# # 2.7

# %%
import matplotlib.pyplot as plt
rolling_avg_wipro = pct_change_dataFrame['WIPRO'].rolling(7).mean()
rolling_avg_wipro
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 490   -0.002460
# 491   -0.000773
# 492   -0.000502
# 493   -0.000701
# 494   -0.007166
# Name: WIPRO, Length: 495, dtype: float64

# %%
stand_wipro = rolling_avg_wipro.fillna(0).std()
stand_wipro
# Out:
# 0.007472522152842465

# %%
import pandas as pd
crrDate = pd.to_datetime(clean_wipro['Date']  )
crrLis = crrDate.tolist()
plt.figure(figsize=(20,10))
plt.plot(crrLis,rolling_avg_wipro.fillna(0).tolist())
plt.show()

# %% [markdown]
# # 2.8

# %%
nif_load=pd.read_csv('D:\\Study\\TY_BTECH\\Resume\\Internship\\CL_Data_School\\Nifty50\\Nifty50\\Nifty50.csv')
nif_load
# Out:
#             Date      Open      High       Low     Close  Shares Traded  \
# 0    15-May-2017   9433.55   9449.25   9423.10   9445.40      145163953
# 1    16-May-2017   9461.00   9517.20   9456.35   9512.25      171709433
# 2    17-May-2017   9517.60   9532.60   9486.10   9525.75      211856040
# 3    18-May-2017   9453.20   9489.10   9418.10   9429.45      199340647
# 4    19-May-2017   9469.90   9505.75   9390.75   9427.90      259861396
# ..           ...       ...       ...       ...       ...            ...
# 489  07-May-2019  11651.50  11657.05  11484.45  11497.90      337495624
# 490  08-May-2019  11478.70  11479.10  11346.95  11359.45      372826025
# 491  09-May-2019  11322.40  11357.60  11255.05  11301.80      373028059
# 492  10-May-2019  11314.15  11345.80  11251.05  11278.90      387323416
# 493  13-May-2019  11258.70  11300.20  11125.60  11148.20      357586433
#
#      Turnover (Rs. Cr)
# 0              7790.97
# 1              9209.89
# 2             10726.23
# 3             10782.46
# 4             11544.77
# ..                 ...
# 489           16632.84
# 490           17440.01
# 491           17602.86
# 492           18085.19
# 493           16722.91
#
# [494 rows x 7 columns]

# %%
nif_close_price = nif_load['Close']
nif_change = nif_close_price.pct_change().fillna(0).rolling(7).mean().fillna(0)
nifDate = pd.to_datetime(nif_load['Date'])
nifDate = nifDate.tolist()
plt.figure(figsize=(20,10))

tcs_Date = pd.to_datetime(clean_tcs['Date'])
tcsLis = tcs_Date.tolist()
tcs_close_price = filter_tcs['Close Price']
tcs_change = tcs_close_price.pct_change().fillna(0).rolling(7).mean().fillna(0)
plt.figure(figsize=(20,10))
plt.plot(tcsLis,rolling_avg_wipro.fillna(0).tolist())

plt.title("Volatility of NIFTY with respect to tcs and wipro")
plt.plot(nifDate,nif_change.tolist(),label = 'nifty')
plt.plot(crrLis,rolling_avg_wipro.fillna(0).tolist(),label = 'wipro')
plt.plot(tcsLis,tcs_change,label = 'tcs')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # 2.9

# %%
# we will use tcs stocks for applying buy/sell signals
plt.figure(figsize=(20,10))
plt.plot(tcsLis,tcs_change,label = 'tcs')
plt.legend(loc='upper left')
plt.show()

# %%
#making short and long signals
import numpy as np
short_window = 21
long_window = 34

signals = pd.DataFrame(index=filter_tcs.index)
signals['signal'] = 0.0

#SMA of Short Window
signals['short_mavg'] = filter_tcs['Close Price'].rolling(window=short_window, min_periods=1,center=False).mean()

#SMA of Long Window
signals['long_mavg'] = filter_tcs['Close Price'].rolling(window=long_window,min_periods=1, center=False).mean()

#Create signals
signals['signal'][short_window:] = np.where(signals['short_mavg'][short_window:] > signals['long_mavg'][short_window:], 1.0,0.0)

#Generate trading orders
signals['positions'] = signals['signal'].diff()
print(signals)

filter_tcs
# Out:
#      signal   short_mavg    long_mavg  positions
# 0       0.0  2347.550000  2347.550000        NaN
# 1       0.0  2339.750000  2339.750000        0.0
# 2       0.0  2371.483333  2371.483333        0.0
# 3       0.0  2397.562500  2397.562500        0.0
# 4       0.0  2405.940000  2405.940000        0.0
# ..      ...          ...          ...        ...
# 490     1.0  2239.435714  2183.539706        0.0
# 491     1.0  2242.080952  2188.238235        0.0
# 492     1.0  2241.859524  2192.422059        0.0
# 493     1.0  2244.695238  2196.360294        0.0
# 494     1.0  2244.552381  2198.350000        0.0
#
# [495 rows x 4 columns]
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0      TCS     EQ  06-Jul-2017     2356.00      2359.0     2361.90    2340.10
# 1      TCS     EQ  07-Jul-2017     2347.55      2350.0     2356.45    2325.50
# 2      TCS     EQ  10-Jul-2017     2331.95      2341.0     2444.90    2341.00
# 3      TCS     EQ  11-Jul-2017     2434.95      2426.0     2514.80    2426.00
# 4      TCS     EQ  12-Jul-2017     2475.80      2482.5     2483.30    2430.10
# ..     ...    ...          ...         ...         ...         ...        ...
# 490    TCS     EQ  01-Jul-2019     2227.20      2235.0     2255.00    2206.60
# 491    TCS     EQ  02-Jul-2019     2239.55      2244.9     2257.00    2216.45
# 492    TCS     EQ  03-Jul-2019     2252.10      2252.2     2258.80    2232.00
# 493    TCS     EQ  04-Jul-2019     2237.65      2234.0     2252.00    2230.10
# 494    TCS     EQ  05-Jul-2019     2242.65      2247.0     2250.00    2140.00
#
#      Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       2350.05      2347.55        2348.75                 513394
# 1       2332.00      2331.95        2343.49                 616045
# 2       2435.00      2434.95        2426.54                 398392
# 3       2482.50      2475.80        2478.13                1768752
# 4       2441.00      2439.45        2453.34                1323225
# ..          ...          ...            ...                    ...
# 490     2233.05      2239.55        2237.15                2769940
# 491     2254.30      2252.10        2237.79                1771746
# 492     2234.00      2237.65        2242.16                1656881
# 493     2241.00      2242.65        2241.04                 984140
# 494     2166.85      2163.10        2179.39                4088470
#
#          Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# 0    1.205835e+09          26826           342973                   66.81
# 1    1.443698e+09          52731           417958                   67.85
# 2    9.667144e+08          12486           188289                   47.26
# 3    4.383195e+09          96054           937311                   52.99
# 4    3.246316e+09          62259           926229                   70.00
# ..            ...            ...              ...                     ...
# 490  6.196759e+09         129268          1579799                   57.03
# 491  3.964797e+09          97184           816451                   46.08
# 492  3.714997e+09          87941           739089                   44.61
# 493  2.205502e+09          59990           352899                   35.86
# 494  8.910375e+09         160276          1736073                   42.46
#
# [495 rows x 15 columns]

# %%
#Initialize the plot figure
fig = plt.figure(figsize=(20,15))

#Add a subplot and label for y-axis
ax1 = fig.add_subplot(111, ylabel='Price')

#Plot the closing price
clean_tcs['Close Price'].plot(ax=ax1, color='black', lw=2.)

#plot the short and long moving averages
signals[['short_mavg', 'long_mavg']].plot(ax=ax1, lw=2.)

#Plot the buy signals
ax1.plot(signals.loc[signals.positions == 1.0].index, signals.short_mavg[signals.positions == 1.0], '^' , markersize=20,color='g')

#Plot the sell signals
ax1.plot(signals.loc[signals.positions == -1.0].index, signals.short_mavg[signals.positions == -1.0], 'v' , markersize=20,color='r')

plt.show()

# %% [markdown]
# # 2.10

# %%
import pandas as pd
import matplotlib.pyplot as plt

symbol = 'TCS'

# read csv file, use date as index and read close as a column
data5 = pd.read_csv('D:\\Study\\TY_BTECH\Resume\\Internship\\CL_Data_School\\ML_Project\\tcs_stock_data.csv'.format(symbol), index_col='Date',
                 parse_dates=True, usecols=['Date', 'Close Price'],
                 na_values='nan')

# rename the column header with symbol name
data5 = data5.rename(columns={'Close Price': symbol})
data5.dropna(inplace=True)

# calculate Simple Moving Average with 14 days window
sma = data5.rolling(window=14).mean()

# calculate the standar deviation
rstd = data5.rolling(window=14).std()

upper_band = sma + 2 * rstd
upper_band = upper_band.rename(columns={symbol: 'upper'})
lower_band = sma - 2 * rstd
lower_band = lower_band.rename(columns={symbol: 'lower'})
data5 = data5.join(upper_band).join(lower_band)
ax = data5.plot(title='{} Price and BB'.format(symbol))
ax.set_xlabel('Date')
ax.set_ylabel('SMA and BB')
ax.grid()
plt.show()
